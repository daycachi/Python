# %% [markdown]
#                                                          **Python for Data Analysts: Methods & Tools - DAT-7466 - FMBAN1**
#
# <center><b>A2: Text Adventure Game Development</b></center>
#
#
#
#
# __Have you ever heard about Grey's anatomy?__
#
# Grey's anatomy is a medical based drama centered around Meredith Grey, an aspiring surgeon and
# daughter of one of the best surgeons, Dr. Ellis Grey.
# Throughout the series, Meredith goes through professional and
# personal challenges along with fellow surgeons at Seattle Grace Hospital.
# This serie has 19 seasons, started on 2005 and the last season was realeased this year.
# Personally I think the success of this serie is because points controversial topics and thought decisions which makes
# the audience empathize with the characters.
#
# __Rules:__
#
# In this game you will have to answer 3 questions:
#
# - The game is composed of 3 trivias.
#
# - In each trivia you only have one chance to solve the question,  if you don't guess the correct answer still you will pass to the next trivia, but you won't get a passcode. However you will get to know more about the serie by getting to know more about your wrong option.
#
# - You win if you provide the 3 passcodes correctly, otherwise you fail or you can restart the game again.
#
# The first trivia is called: "Into You Like a Train"
# And you will have to guess who participated in the complicated surgery.
#
# The second trivia is called: "Bye Bye 007"
# You will have to guess which doctor died.
#
# The third trivia is called: "Who said what?"
# You will be given a random quote, and you will have to guess who said that.
#
#
# __APA reference:__
#
# Heinberg, A. (Producer), Rhimes, S. (Writer), & Rhimes, S. (Director). (2005). Grey's Anatomy [Motion Picture]. US: Disney–ABC Domestic Television. Retrieved from https://en.wikipedia.org/wiki/Grey%27s_Anatomy#:~:text=Grey's%20Anatomy%20is%20an%20American,balancing%20personal%20and%20professional%20relationships.
#
#
# |![alt](https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/greys-anatomy-focuses-on-young-people-struggling-to-be-news-photo-93765020-1551297480.jpg?crop=0.718xw:1.00xh;0.199xw,0&resize=640:*)

# %%
#############################################################################################################
import os # to add new line in f-strings
import random # for creating a random quote to the user


# creating a user define function called "start" that will ask to the user to start 
def start():

    while True:
        
        choice = input(prompt = "\nPress 1 to either start or resume the game or press 2 to exit of the game.\n\n")
        
        try:
            choice = int(choice)
        
        except:
            input(prompt = 'Insert numbers please')
            continue

        # if stament comparing to 1 in case the user wants to re start the game
        if choice == 1:
            trivia_1()
                
 
            # if user press 2 is to quit the game
        elif choice == 2:
            fail()
            pass
            break
                

        else:
            print('Something went wrong. Type a valid answer')
            start()
                


# creating a user define function called trivia_1 which is the first stage in this game

def trivia_1():
    
    
    print(f'***************************************** THIS IS TRIVIA 1 *********************************************************')
        
    print('''\nWelcome to Grey's Anatomy Trivia Game!''')
    print('''\nYou are in Trivia 1: "Into like Train"
\n\nThere was a big accident in the city so several pacients are arriving to the hospital.
\nHowever there is one case that is taking the attention of everbody. 
\nTwo patients have been impaled by a metal pole that have crossed both of them compromising
\nmore than one organ of both.''')
    
    # creating a list called "characters_list" which contains the name of serie's characters
    characters_list = [[0,"name","speciliaty"], #header
                       [1,"meredith", "general surgeon"], 
                       [2,"dereck","neurology surgeon"], 
                       [3,"izzie", "oncology surgeon"], 
                       [4,"george", "trauma surgeon"],
                       [5,"christina", "cardiothoracic surgeon"],
                       [6,"alex", "pediatric surgeon"]]
    
    # creating a list that will contain only the numbers for the options given, in case the user insert an option outside of the correct range of options
    valid_numbers = list(range(1,8,1))#creating a list for valid options
    
    # applying a while funtion with try and except clauses to handle possible error input from the user side
    while True:
        # to display the dialog box
        choice_1 = input(prompt = f"""\nQUESTION: Which surgeon do you think took part on it?:\n\nInsert a number please from the list:\n\n**HINT: Team collaboration is everything
                                 
                                 
                                 1. General surgeon
                                 2. Neurology surgeon
                                 3. Oncology surgeon
                                 4. Trauma surgeon
                                 5. Cardiothoracic1 surgeon
                                 6. Pediatric surgeon
                                 7. Multiple surgeons
                                 
                            """)
        try:
            # converting choice for numerical comparison
            choice_1 = int(choice_1)

            # except clause to handle the possible error with a message to the user to manage his mistake
        except: 
            input(prompt = "\nYou need to insert a number. Press enter to try again.\n")
            continue

        # conditional statement based on the user input compared to the correct answer
        if choice_1 == 7:
            print(f"{os.linesep}CONGRATULATIONS: CORRECT ANSWER: Multiple surgeons participated in this complicated surgery which were a {characters_list[1][2]}, a {characters_list[2][2]}, and a {characters_list[5][2]}.{os.linesep}SAVE THIS PASSCODE: 3")
            trivia_2()
            break
            

         
        # conditional statement elif based on the user input in case the answer is different from the correct
        elif choice_1 !=7:
            # nested if condition in case the user input is incorrect but is a number from the valid list of options
            if choice_1 in valid_numbers:
                for number,name,speciality in characters_list:
                    # printing the passcode and details about correct answer as well as details about the user's choice
                    print(f"{os.linesep}WRONG ANSWER: In this surgery participated: {os.linesep} - Dr. Meredith (General surgeon) {os.linesep} - Dr. Dereck Shepherd (Neurologist) {os.linesep} - Dr. Yang (Cardiologist), unfortunatelly you loose one point, good luck in the next trivia{os.linesep} BONUS: Your choice number {choice_1} corresponds to the {characters_list[choice_1][2].capitalize()} Dr. {characters_list[choice_1][1].capitalize()} {os.linesep}{os.linesep}")
                    # calling trivia_2()
                    trivia_2()
                    break
                    

            # else clause in case the user inserts a number different from 7 and also outside of the range of valid options
            else:
                print("Insert an option from the list. Try again")
                trivia_1()
                break
                
         
    # in case something goes wrong
        else:
            print("\n.Try again/n")
            trivia_1()
            break
            

# creating a user define function for trivia_2
def trivia_2():
    
    print(f'\n\n********************************** THIS IS TRIVIA 2 ************************************************************')

    # welcoming the user to the trivia_2
    print('''\nYou're in trivia 2! "Bye Bye 007" ''')

    # creating again a list with a different name for this function trivia_2()
    characters_list2 = [[int(0),"name","speciliaty"],
                       [int(1),"meredith", "general surgeon"], 
                       [int(2),"shepherd","neurology surgeon"], 
                       [int(3),"izzie", "oncology surgeon"], 
                       [int(4),"george", "trauma surgeon"],
                       [int(5),"christina", "cardithoracic surgeon"],
                       [int(6),"alex", "pediatric surgeon"]]

    print(''''\nIn this trivia you have to guess who died first, on the season 6 episode 1, one of the characters die.
\nThis doctor had decided to quit to his job at the hospital.He never imagined he could die before of it. 
\nHe was in the middle of the city about to cross the whitelines, the lights where in red for the vehicules and 
\nthere was not visible cars aproching, which meant it was safe to cross. However a bus pass out of no where like 
\na lightning while a girl was starting to cross. THe doctor saved her life but got hitted by the bus.
\nWhen he arrived to the hospital he was impossible to recognize, but could manage to write with his finger the number "007" on the palm of Meredith ''')
    
    # creating a list of valid options 
    valid_numbers2 = list(range(1,7,1))


    # using while true function with try and except clauses to handle possible error from the user's input
    while True:
        choice_2 = input(prompt = f""" QUESTION: Which of the surgeon do you think was 007?\n\nInsert a number please from the list given:\n**HINT: 'He wanted to go the war because he wanted to learn to work under pressure and improve his career in trauma'

                                 1. Dr. Meredith Gray
                                 2. Dr. Dereck Shepherd
                                 3. Dr. Issie Stevens
                                 4. Dr. George O'Maley
                                 5. Dr. Christina Yang
                                 6. Dr. Alex Karev

    """)

        try:
            # converting choice for numerical comparison
            choice_2 = int(choice_2)

        except:
            input(prompt = "\nYou need to insert a number. Press enter to try again.\n")
            continue

        # conditional statement based on user input comparinf to the correct answer
        if choice_2 == 4:
            print(f"{os.linesep}CORRECT ANSWER, CONGRATULATIONS Dr. {characters_list2[4][1]} died saving a life before go to the war.{os.linesep}SAVE THIS PASSCODE: 27")
            trivia_3()
            break
           
            
            # break
        # elif statement in case the user input is different from the correct answer
        elif choice_2 != 4:
                # nested if conditional statement in case the user input is incorrect but inside the range of valid answers
                if choice_2 in valid_numbers2:
                    #{os.linesep} to add new line in f-strings
                    print(f"{os.linesep}WRONG ANSWER: BONUS Dr. {characters_list2[choice_2][1].capitalize()} is a {characters_list2[choice_2][2].capitalize()}>>{os.linesep}{os.linesep}")
                    trivia_3()
                    break
                  
                    
                # nested else conditional statement in case the user input is incorrect and outside of the range of valid answers    
                else:
                    print('Insert an option from the given list')
                
        
    # setting a different error message in case something goes wrong
        else:

            print("\n.Your number is not in the range. Try again/n")
            #calling trivia_2()
            trivia_2()
            break
           
            

# creating a user define functions for trivia_3            
def trivia_3():
    
    print(f'\n\n********************************** THIS IS TRIVIA 3 ************************************************************')

    # welcoming the user to the trivia_3
    print('''\nYou're in trivia ! "Who said what?" ''')


    # creating a dictionary having the characters names as key and their respective quote as values. 
    quotes_dict = {
            "Meredith": """ "Is this the life you want to live'? Is this the person you want to love? Is this the best you can be?\nBreathe in.\nBreathe out & decide." """,
            "Dereck": """ "It is a beautiful day to save lives" """,
            "Christina": """ "Meredith, don't let what he wants eclipse what you need. He's very dreamy but he's not the sun, you are." """,
            "George": """  "Izzie and Meredith and Cristina...they're my family." """,
            "Izzie": """  "That's How You Stay Alive. When It Hurts So Much You Can't Breathe,\nThat's How You Survive." """,
            "Alex": """ "At the end of the day, all that matters is what you think" """
                      }


    print('''\n\nIn this trivia you will have to guess who said the following quote: ''')

    # selecting a random item from the dictionary 'quotes_dict'
    item_dictionary = random.choice(list(quotes_dict))

    # fetching value using item_dict
    print(f"{os.linesep}The quote ramdonly selected for you is: {os.linesep}{os.linesep}<<{quotes_dict[item_dictionary]}>> ")

    # creating a list with valid options for the character's name
    valid_names = ['Meredith','Dereck','Izzie','George','Christina','Alex']

    # using while true function with try and except clauses to handle possible error from the user's input
    while True:
        # creating a variable to get the user input answer for the trivia
        choice_3 = input(prompt = f"""\nQUESTION: Which of the following surgeon do you think said the quote?\n\nType one of the following names:

                                     Meredith
                                     Dereck 
                                     Izzie
                                     George 
                                     Christina
                                     Alex 

                    """)
        # converting the user input into a string and capitalizing to match with the keys in the dictionary
        try:
            choice_3 = str(choice_3).capitalize()

        except:
            input(prompt = "\nYou need to insert a string. Press enter to try again.\n")

            continue

        # conditional if statement based on user input comparing to the range of valid options
        if choice_3 in valid_names:
            if choice_3 not in item_dictionary:
                print(f"{os.linesep}INCORRECT ANSWER: Nice guess, but actually the Dr. {choice_3} said {quotes_dict[choice_3]}")
                password()
                break
            
            
            else:
                print(f'\nCORRECT ANSWER. CONGRATULATION! Good job guessing the name of Dr. {choice_3}{os.linesep}SAVE THIS PASSCODE: 2005')
                password()
                break
                
            
        
        # in case something goes wrong
        else:
            print("\nSomethig wet wrong, insert a valid option. Try again")  
            trivia_3()
            break
          
            

# creatind a user define function that will ask for the passcodes and count the attempts if is more than than three the game well resume, or if the user wants as well
def password():

        # creating a variable that contains the password which is an integer
    correct_password = int(3272005)  
    
    print(f'\n\n********************************** PASSWORD TIME ************************************************************')
    print(f'\n\nIt is time of the truth, you will be asked for the secret codes in order to win')
        
    # using a while True funtion with try and except clauses to handle possible error from the user side  
    while True:
        
        user_password = input(prompt = "\nPlease enter the 3 numbers collected if you have them. If not press 0.\n\n")
        
        try:
            user_password = int(user_password)
        
        except:
            input(prompt = 'Insert numbers please')
            
            continue

        # if stament comparing to 0 user fails
        if user_password == 0:
            fail()
            break
            

            # if user insert correct passcode wins
        elif user_password == correct_password:
            win()
            break

        else:
            print('Something went wrong. Type a valid answer')
            password()
            break
    

# creating a user defeine funtion for winning
def win():
    print('\nGOB JOB CONGRATULATIONS YOU WIN!!!')
    start()
   
 # creating a user define function that will make the user fail or choose to fail
def fail():
    print('BYE, GAME OVER')
    
    play_again = input(prompt = "Would you like to play again? (Y/N)")
    
    if play_again.lower() == 'y': # user wants to play again
        start()
        
    elif play_again.lower() == 'n':
        print("Thanks for playing. Good bye!")
        
    else:
        pass

start()
